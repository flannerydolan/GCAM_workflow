# %%
import xml.etree.ElementTree as ET

# %%
# first read in base configuration file

# %%
tree=ET.parse('/cluster/tufts/lamontagnelab/fdolan03/GCAM/gcam-core/exe/configuration_readin.xml')

# %%
root=tree.getroot()

# %%
scenComp=root.find('ScenarioComponents')

# %%
import numpy as np

# %%
# make arrays of all xml files of SSPs for each group

# %%
np_ssps=np.array(['../input/gcam-data-system/xml/socioeconomics-xml/socioeconomics_SSP1.xml',
         '../input/gcam-data-system/xml/socioeconomics-xml/socioeconomics_SSP2.xml',
         '../input/gcam-data-system/xml/socioeconomics-xml/socioeconomics_SSP3.xml',
         '../input/gcam-data-system/xml/socioeconomics-xml/socioeconomics_SSP4.xml',
         '../input/gcam-data-system/xml/socioeconomics-xml/socioeconomics_SSP5.xml'])

# %%
food_aglus=np.array(['../input/gcam-data-system/xml/aglu-xml/food_SSP1.xml',
                     '../input/gcam-data-system/xml/aglu-xml/food_SSP2.xml',
                     '../input/gcam-data-system/xml/aglu-xml/food_SSP3.xml',
                     '../input/gcam-data-system/xml/aglu-xml/food_SSP4.xml',
                     '../input/gcam-data-system/xml/aglu-xml/food_SSP5.xml'])
mgmt_aglus=np.array(['../input/gcam-data-system/xml/aglu-xml/ag_prodchange_ssp1_IRR_MGMT.xml',
                     '../input/gcam-data-system/xml/aglu-xml/ag_prodchange_ssp2_IRR_MGMT.xml',
                     '../input/gcam-data-system/xml/aglu-xml/ag_prodchange_ssp3_IRR_MGMT.xml',
                     '../input/gcam-data-system/xml/aglu-xml/ag_prodchange_ssp4_IRR_MGMT.xml',
                     '../input/gcam-data-system/xml/aglu-xml/ag_prodchange_ssp5_IRR_MGMT.xml'])

# %%
np_aglu=np.column_stack((food_aglus,mgmt_aglus))

# %%
inds=np.array(['../input/gcam-data-system/xml/energy-xml/industry_incelas_ssp1.xml',
             '../input/gcam-data-system/xml/energy-xml/industry_incelas_ssp2.xml',
             '../input/gcam-data-system/xml/energy-xml/industry_incelas_ssp3.xml',
             '../input/gcam-data-system/xml/energy-xml/industry_incelas_ssp4.xml',
             '../input/gcam-data-system/xml/energy-xml/industry_incelas_ssp5.xml'])
cem=np.array(['../input/gcam-data-system/xml/energy-xml/cement_incelas_ssp1.xml',
             '../input/gcam-data-system/xml/energy-xml/cement_incelas_ssp2.xml',
             '../input/gcam-data-system/xml/energy-xml/cement_incelas_ssp3.xml',
             '../input/gcam-data-system/xml/energy-xml/cement_incelas_ssp4.xml',
             '../input/gcam-data-system/xml/energy-xml/cement_incelas_ssp5.xml'])

# %%
np_ind=np.column_stack((inds,cem))

# %%
np_trans=np.array(['../input/extra/Sean/transportation_UCD_SSP1.xml',
                  '../input/extra/Sean/transportation_UCD_SSP2.xml',
                  '../input/extra/Sean/transportation_UCD_SSP3.xml',
                   '../input/extra/Sean/transportation_UCD_SSP3.xml',
                   '../input/extra/Sean/transportation_UCD_SSP5.xml'])

# %%
np_build=np.array(['../input/gcam-data-system/xml/energy-xml/building_SSP1.xml',
                  '../input/gcam-data-system/xml/energy-xml/building_SSP2.xml',
                  '../input/gcam-data-system/xml/energy-xml/building_SSP3.xml',
                  '../input/gcam-data-system/xml/energy-xml/building_SSP4.xml',
                  '../input/gcam-data-system/xml/energy-xml/building_SSP5.xml'])

# %%
np_ccs=np.array(['../input/gcam-data-system/xml/energy-xml/ccs_supply_lowest.xml',
                '../input/gcam-data-system/xml/energy-xml/ccs_supply_low.xml',
                '../input/gcam-data-system/xml/energy-xml/ccs_supply_low.xml',
                '../input/gcam-data-system/xml/energy-xml/ccs_supply_high.xml',
                '../input/gcam-data-system/xml/energy-xml/ccs_supply_high.xml'])

# %%
np_fossil=np.array(['../input/gcam-data-system/xml/energy-xml/resources_SSP1.xml',
                   '../input/gcam-data-system/xml/energy-xml/resources_SSP2.xml',
                   '../input/gcam-data-system/xml/energy-xml/resources_SSP3.xml',
                   '../input/gcam-data-system/xml/energy-xml/resources_SSP4.xml',
                   '../input/gcam-data-system/xml/energy-xml/resources_SSP5.xml'])

# %%
np_neg=np.array(['../input/gcam-data-system/xml/energy-xml/negative_emissions_budget_SSP1.xml',
                '../input/gcam-data-system/xml/energy-xml/negative_emissions_budget_SSP2.xml',
                '../input/gcam-data-system/xml/energy-xml/negative_emissions_budget_SSP3.xml',
                '../input/gcam-data-system/xml/energy-xml/negative_emissions_budget_SSP4.xml',
                '../input/gcam-data-system/xml/energy-xml/negative_emissions_budget_SSP5.xml'])

# %%
np_nonco21=np.array(['../input/gcam-data-system/xml/emissions-xml/delete_gdp_control.xml',
          '../input/gcam-data-system/xml/emissions-xml/delete_gdp_control.xml',
          '../input/gcam-data-system/xml/emissions-xml/delete_gdp_control.xml',
          '../input/gcam-data-system/xml/emissions-xml/delete_gdp_control.xml',
          '../input/gcam-data-system/xml/emissions-xml/delete_gdp_control.xml'])

# %%
np_nonco22=np.array(['../input/gcam-data-system/xml/emissions-xml/ssp15_emissions_factors.xml',
                     '../input/gcam-data-system/xml/emissions-xml/ssp2_emissions_factors.xml',
                     '../input/gcam-data-system/xml/emissions-xml/ssp34_emissions_factors.xml',
                     '../input/gcam-data-system/xml/emissions-xml/ssp34_emissions_factors.xml',
                     '../input/gcam-data-system/xml/emissions-xml/ssp15_emissions_factors.xml'])

# %%
np_crop_yield_ssp1=np.array(['../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_gfdl_pdssat_SSP1.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_hadgem2_pdssat_SSP1.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_ipsl_pdssat_SSP1.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP1.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_noresm1_pdssat_SSP1.xml'])
np_crop_yield_ssp2=np.array(['../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_gfdl_pdssat_SSP2.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_hadgem2_pdssat_SSP2.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_ipsl_pdssat_SSP2.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP2.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_noresm1_pdssat_SSP2.xml'])
np_crop_yield_ssp3=np.array(['../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_gfdl_pdssat_SSP3.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_hadgem2_pdssat_SSP3.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_ipsl_pdssat_SSP3.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP3.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_noresm1_pdssat_SSP3.xml'])
np_crop_yield_ssp4=np.array(['../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_gfdl_pdssat_SSP4.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_hadgem2_pdssat_SSP4.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_ipsl_pdssat_SSP4.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP4.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_noresm1_pdssat_SSP4.xml'])
np_crop_yield_ssp5=np.array(['../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_gfdl_pdssat_SSP5.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_hadgem2_pdssat_SSP5.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_ipsl_pdssat_SSP5.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP5.xml',
                           '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_noresm1_pdssat_SSP5.xml'])


np_crop_yield=np.column_stack((np_crop_yield_ssp1,np_crop_yield_ssp2,np_crop_yield_ssp3,np_crop_yield_ssp4,np_crop_yield_ssp5))

# %%
np_crop_yield[3][0]
# Out:
# '../input/gcam-data-system/xml/water-xml/crop_yield/ag_prodchange_rcp4p5_miroc_pdssat_SSP1.xml'

# %%
np_hydropower=np.array(['../input/gcam-data-system/xml/water-xml/hydropower/hydro_gfdl-esm2m_4p5.xml',
                       '../input/gcam-data-system/xml/water-xml/hydropower/hydro_hadgem2-es_4p5.xml',
                       '../input/gcam-data-system/xml/water-xml/hydropower/hydro_ipsl-cm5a-lr_4p5.xml',
                       '../input/gcam-data-system/xml/water-xml/hydropower/hydro_miroc-esm-chem_4p5.xml',
                       '../input/gcam-data-system/xml/water-xml/hydropower/hydro_noresm1-m_4p5.xml'])

# %%
np_water_supply_rs=np.array(['../input/gcam-data-system/xml/water-xml/water_supply/water_cc_gfdl_4p5.xml',
                             '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_hadgem_4p5.xml',
                              '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_ipsl_4p5.xml',
                              '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_miroc_4p5.xml',
                             '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_noresm_4p5.xml'])
np_water_supply_exp=np.array(['../input/gcam-data-system/xml/water-xml/water_supply/water_cc_gfdl_4p5_exp_wg.xml',
                             '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_hadgem_4p5_exp_wg.xml',
                              '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_ipsl_4p5_exp_wg.xml',
                              '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_miroc_4p5_exp_wg.xml',
                             '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_noresm_4p5_exp_wg.xml'])
np_water_supply=np.column_stack((np_water_supply_rs,np_water_supply_exp))

# %%
np_water_supply[3][1]
# Out:
# '../input/gcam-data-system/xml/water-xml/water_supply/water_cc_miroc_4p5_exp_wg.xml'

# %%
np_water_input=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/ag_water_input_ssp1_IRR_MGMT.xml',
                        '../input/gcam-data-system/xml/water-xml/water_demand/ag_water_input_ssp2_IRR_MGMT.xml',
                        '../input/gcam-data-system/xml/water-xml/water_demand/ag_water_input_ssp3_IRR_MGMT.xml',
                        '../input/gcam-data-system/xml/water-xml/water_demand/ag_water_input_ssp4_IRR_MGMT.xml',
                        '../input/gcam-data-system/xml/water-xml/water_demand/ag_water_input_ssp5_IRR_MGMT.xml'])
np_electricity_water_coefs=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_coefs_ssp1.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_coefs_ssp2.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_coefs_ssp3.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_coefs_ssp4.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_coefs_ssp5.xml'])
np_electricity_water=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_ssp1.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_ssp2.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_ssp3.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_ssp4.xml',
                              '../input/gcam-data-system/xml/water-xml/water_demand/electricity_water_ssp5.xml'])
np_resbio=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/resbio_input_ssp1_IRR_MGMT.xml',
                   '../input/gcam-data-system/xml/water-xml/water_demand/resbio_input_ssp2_IRR_MGMT.xml',
                   '../input/gcam-data-system/xml/water-xml/water_demand/resbio_input_ssp3_IRR_MGMT.xml',
                   '../input/gcam-data-system/xml/water-xml/water_demand/resbio_input_ssp4_IRR_MGMT.xml',
                   '../input/gcam-data-system/xml/water-xml/water_demand/resbio_input_ssp5_IRR_MGMT.xml'])
np_water_demand_industry=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/water_demand_industry_ssp1.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_industry_ssp2.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_industry_ssp3.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_industry_ssp4.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_industry_ssp5.xml'])
np_water_demand_municipal=np.array(['../input/gcam-data-system/xml/water-xml/water_demand/water_demand_municipal_mod_ssp1.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_municipal_mod_ssp2.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_municipal_mod_ssp3.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_municipal_mod_ssp4.xml',
                                  '../input/gcam-data-system/xml/water-xml/water_demand/water_demand_municipal_mod_ssp5.xml'])

# %%
np_gw=(['../input/gcam-data-system/xml/water-xml/old/water_supply_wg_lo.xml',
       '../input/gcam-data-system/xml/water-xml/old/water_supply_wg_md.xml',
       '../input/gcam-data-system/xml/water-xml/old/water_supply_wg_hi.xml'])

# %%
gw_list=['lo','med','hi']

# %%
range(len(gw_list))
# Out:
# [0, 1, 2]

# %%
root[0][4].text
# Out:
# '../output/database_basexdb_seantest'

# %%
res_list=['rs','exp']

# %%
gcm_list=['gfdl','hadgem','ipsl','miroc','noresm']

# %%
lud_list=['uct','ffict']

# %%
np_lud=(['../input/policy/global_uct.xml','../input/policy/global_ffict.xml'])

# %%
# one loop creates configuration files where the other elements of the SSPs are tied to the socioeconomics and the other creates config files where the elements are tied to the AGLU SSP.

# %%
# for ssp in range(len(np_ssps)):
#     for ag in range(len(np_aglu)):
#         for gcm in range(len(np_hydropower)):
#             for res in range(len(res_list)):
#                 for gw in range(len(gw_list)):
#                     for lud in range(len(lud_list)):
#                         #lud
#                         lud_type=ET.SubElement(scenComp,tag='Value')
#                         lud_type.attrib={'name':'lud'}
#                         lud_type.text=np_lud[lud]
#                         #low,med,high gw
#                         gw_supply=ET.SubElement(scenComp,tag='Value')
#                         gw_supply.attrib={'name':'water_supply'}
#                         gw_supply.text=np_gw[gw]
#                         #Sean climate impacts xmls
#                         hydro=ET.SubElement(scenComp,tag='Value')
#                         hydro.attrib={'name':'climate_hydro'}
#                         hydro.text=np_hydropower[gcm]
#                         cropyield=ET.SubElement(scenComp,tag='Value')
#                         cropyield.attrib={'name':'aglu'}
#                         cropyield.text=np_crop_yield[gcm][ag]
#                         runoff=ET.SubElement(scenComp,tag='Value')
#                         runoff.attrib={'name':'climate_runoff'}
#                         #expanded vs restricted reservoir storage
#                         runoff.text=np_water_supply[gcm][res]
#                         #aglu
#                         food=ET.SubElement(scenComp,tag='Value')
#                         food.text=np_aglu[ag,0]
#                         food.attrib={'name': 'aglu'}
#                         mgmt=ET.SubElement(scenComp,tag='Value')
#                         mgmt.text=np_aglu[ag,1]
#                         mgmt.attrib={'name': 'aglu'}
#                         #the rest of ssp elements (tied to pop/gdp now but can change to aglu by indexing for ag)
#                         soc=ET.SubElement(scenComp,tag='Value')
#                         soc.text=np_ssps[ssp]
#                         soc.attrib={'name': 'socioeconomics'}
#                         ind=ET.SubElement(scenComp,tag='Value')
#                         ind.text=np_ind[ag,0]
#                         ind.attrib={'name':'ind'}
#                         cem=ET.SubElement(scenComp,tag='Value')
#                         cem.text=np_ind[ag,1]
#                         cem.attrib={'name':'cement'}
#                         trans=ET.SubElement(scenComp,tag='Value')
#                         trans.text=np_trans[ag]
#                         trans.attrib={'name':'trn'}
#                         build=ET.SubElement(scenComp,tag='Value')
#                         build.text=np_build[ag]
#                         build.attrib={'name':'bld'}
#                         ccs=ET.SubElement(scenComp,tag='Value')
#                         ccs.text=np_ccs[ag]
#                         ccs.attrib={'name':'ccs'}
#                         fossil=ET.SubElement(scenComp,tag='Value')
#                         fossil.text=np_fossil[ag]
#                         fossil.attrib={'name':'resource_extraction'}
#                         nonco21=ET.SubElement(scenComp,tag='Value')
#                         nonco21.text=np_nonco21[ag]
#                         nonco21.attrib={'name':'nonco2'}
#                         nonco22=ET.SubElement(scenComp,tag='Value')
#                         nonco22.text=np_nonco22[ag]
#                         nonco22.attrib={'name':'nonco2'}
#                         neg=ET.SubElement(scenComp,tag='Value')
#                         neg.attrib={'name':'bio_neg_emiss_budget'}
#                         neg.text=np_neg[ag]
#                         #Neal's water demand xmls
#                         waterinput=ET.SubElement(scenComp,tag='Value')
#                         waterinput.attrib={'name':'water_input'}
#                         waterinput.text=np_water_input[ag]
#                         electricitywatercoef=ET.SubElement(scenComp,tag='Value')
#                         electricitywatercoef.attrib={'name':'electricity_water_coef'}
#                         electricitywatercoef.text=np_electricity_water_coefs[ag]
#                         electricitywater=ET.SubElement(scenComp,tag='Value')
#                         electricitywater.attrib={'name':'electricity_water'}
#                         electricitywater.text=np_electricity_water[ag]
#                         resbio=ET.SubElement(scenComp,tag='Value')
#                         resbio.attrib={'name':'resbio'}
#                         resbio.text=np_resbio[ag]
#                         waterdemandindustry=ET.SubElement(scenComp,tag='Value')
#                         waterdemandindustry.attrib={'name':'water_demand_industry'}
#                         waterdemandindustry.text=np_water_demand_industry[ag]
#                         waterdemandmunicipal=ET.SubElement(scenComp,tag='Value')
#                         waterdemandmunicipal.attrib={'name':'water_demand_municipal'}
#                         waterdemandmunicipal.text=np_water_demand_municipal[ag]


#                         #change the scenario name
#                         scen=('ssp_ag'+str(ag+1)+'_soc'+str(ssp+1)+'_gw'+gw_list[gw]+'_'+res_list[res]+'_'+gcm_list[gcm]+'_NDC_Tax_'+lud_list[lud])
#                         root[2][0].text=scen
#                         root[0][4].text='../output/'+'ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/db_'+scen

#                         if ag==0:
#                             renew=ET.SubElement(scenComp,tag='Value')
#                             renew.attrib={'name':'share_weights'}
#                             renew.text='../input/extra/renewable_shareweights_ssp1_32.xml'
#                             wind=ET.SubElement(scenComp,tag='Value')
#                             wind.attrib={'name':'wind'}
#                             wind.text='../input/gcam-data-system/xml/energy-xml/wind_adv.xml'
#                             solar=ET.SubElement(scenComp,tag='Value')
#                             solar.attrib={'name':'solar'}
#                             solar.text='../input/gcam-data-system/xml/energy-xml/solar_adv.xml'
#                             geo=ET.SubElement(scenComp,tag='Value')
#                             geo.attrib={'name':'geothermal'}
#                             geo.text='../input/gcam-data-system/xml/energy-xml/geo_adv.xml'
#                             geotech=ET.SubElement(scenComp,tag='Value')
#                             geotech.attrib={'name':'geothermal'}
#                             geotech.text='../input/gcam-data-system/xml/energy-xml/geo_tech_adv.xml'
#                             nuc=ET.SubElement(scenComp,tag='Value')
#                             nuc.attrib={'name':'nuclear'}
#                             nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_low.xml'
#                             ccs2=ET.SubElement(scenComp,tag='Value')
#                             ccs2.attrib={'name':'ccs'}
#                             ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
#                             nonco23=ET.SubElement(scenComp,tag='Value')
#                             nonco23.attrib={'name':'nonco2'}
#                             nonco23.text='../input/gcam-data-system/xml/emissions-xml/MACC_TC_SSP1_IRR_MGMT.xml'
#                             tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/'+scen+'.xml')
#                             scenComp.remove(renew)
#                             scenComp.remove(wind)
#                             scenComp.remove(solar)
#                             scenComp.remove(geo)
#                             scenComp.remove(geotech)
#                             scenComp.remove(nuc)
#                             scenComp.remove(ccs2)
#                             scenComp.remove(nonco23)
#                         elif ag==1:
#                             ccs2=ET.SubElement(scenComp,tag='Value')
#                             ccs2.attrib={'name':'ccs'}
#                             ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
#                             tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/'+scen+'.xml')
#                             scenComp.remove(ccs2)
#                         elif ag==2:
#                             wind=ET.SubElement(scenComp,tag='Value')
#                             wind.attrib={'name':'wind'}
#                             wind.text='../input/gcam-data-system/xml/energy-xml/wind_low.xml'
#                             solar=ET.SubElement(scenComp,tag='Value')
#                             solar.attrib={'name':'solar'}
#                             solar.text='../input/gcam-data-system/xml/energy-xml/solar_low.xml'
#                             geo=ET.SubElement(scenComp,tag='Value')
#                             geo.attrib={'name':'geothermal'}
#                             geo.text='../input/gcam-data-system/xml/energy-xml/geo_low.xml'
#                             bio=ET.SubElement(scenComp,tag='Value')
#                             bio.attrib={'name':'bio'}
#                             bio.text='../input/gcam-data-system/xml/energy-xml/en_transformation_low.xml'
#                             bio2=ET.SubElement(scenComp,tag='Value')
#                             bio2.attrib={'name':'bio'}
#                             bio2.text='../input/gcam-data-system/xml/energy-xml/elec_bio_low.xml'
#                             nuc=ET.SubElement(scenComp,tag='Value')
#                             nuc.attrib={'name':'nuclear'}
#                             nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_low.xml'
#                             ccs2=ET.SubElement(scenComp,tag='Value')
#                             ccs2.attrib={'name':'ccs'}
#                             ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
#                             biotrade=ET.SubElement(scenComp,tag='Value')
#                             biotrade.attrib={'name':'bio_trade'}
#                             biotrade.text='../input/gcam-data-system/xml/aglu-xml/ssp3_bio_trade.xml'

#                             tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/'+scen+'.xml')

#                             scenComp.remove(wind)
#                             scenComp.remove(solar)
#                             scenComp.remove(geo)
#                             scenComp.remove(bio)
#                             scenComp.remove(bio2)
#                             scenComp.remove(nuc)
#                             scenComp.remove(ccs2)
#                             scenComp.remove(biotrade)
#                         elif ag==3:
#                             wind=ET.SubElement(scenComp,tag='Value')
#                             wind.attrib={'name':'wind'}
#                             wind.text='../input/gcam-data-system/xml/energy-xml/wind_adv.xml'
#                             solar=ET.SubElement(scenComp,tag='Value')
#                             solar.attrib={'name':'solar'}
#                             solar.text='../input/gcam-data-system/xml/energy-xml/solar_adv.xml'
#                             geo=ET.SubElement(scenComp,tag='Value')
#                             geo.attrib={'name':'geothermal'}
#                             geo.text='../input/gcam-data-system/xml/energy-xml/geo_adv.xml'
#                             geotech=ET.SubElement(scenComp,tag='Value')
#                             geotech.attrib={'name':'geothermal'}
#                             geotech.text='../input/gcam-data-system/xml/energy-xml/geo_tech_adv.xml'
#                             nuc=ET.SubElement(scenComp,tag='Value')
#                             nuc.attrib={'name':'nuclear'}
#                             nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_adv.xml'
#                             trade=ET.SubElement(scenComp,tag='Value')
#                             trade.attrib={'name':'trade'}
#                             trade.text='../input/gcam-data-system/xml/aglu-xml/ssp4_trade.xml'
#                             biotrade=ET.SubElement(scenComp,tag='Value')
#                             biotrade.attrib={'name':'bio_trade'}
#                             biotrade.text='../input/gcam-data-system/xml/aglu-xml/ssp4_bio_trade.xml'

#                             tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/'+scen+'.xml')

#                             scenComp.remove(wind)
#                             scenComp.remove(solar)
#                             scenComp.remove(geo)
#                             scenComp.remove(geotech)
#                             scenComp.remove(nuc)
#                             scenComp.remove(trade)
#                             scenComp.remove(biotrade)

#                         elif ag==4:
#                             nonco23=ET.SubElement(scenComp,tag='Value')
#                             nonco23.attrib={'name':'nonco2'}
#                             nonco23.text='../input/gcam-data-system/xml/emissions-xml/MACC_TC_SSP2_IRR_MGMT.xml'

#                             tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_ag/'+'ssp_ag'+str(ag+1)+'/soc'+str(ssp+1)+'/'+scen+'.xml')

#                             scenComp.remove(nonco23)

#                         #tree.write('/cluster/home/fdolan03/jupyter/config/'+'ssp'+str(ssp+1)+'/ag'+str(ag+1)+'/ssp'+str(ssp+1)+'ag'+str(ag+1)+.xml')
#                         scenComp.remove(soc)
#                         scenComp.remove(food)
#                         scenComp.remove(mgmt)
#                         scenComp.remove(ind)
#                         scenComp.remove(cem)
#                         scenComp.remove(trans)
#                         scenComp.remove(build)
#                         scenComp.remove(ccs)
#                         scenComp.remove(fossil)
#                         scenComp.remove(nonco21)
#                         scenComp.remove(nonco22)
#                         scenComp.remove(neg)
#                         scenComp.remove(waterinput)
#                         scenComp.remove(electricitywatercoef)
#                         scenComp.remove(electricitywater)
#                         scenComp.remove(resbio)
#                         scenComp.remove(waterdemandindustry)
#                         scenComp.remove(waterdemandmunicipal)

#                         scenComp.remove(hydro)
#                         scenComp.remove(cropyield)
#                         scenComp.remove(runoff)
#                         scenComp.remove(gw_supply)

#                         scenComp.remove(lud_type)

# %%
for ssp in range(len(np_ssps)):
    for ag in range(len(np_aglu)):
        for gcm in range(len(np_hydropower)):
            for res in range(len(res_list)):
                for gw in range(len(gw_list)):
                    for lud in range(len(lud_list)):
                        #lud
                        lud_type=ET.SubElement(scenComp,tag='Value')
                        lud_type.attrib={'name':'lud'}
                        lud_type.text=np_lud[lud]
                        #low,med,high gw
                        gw_supply=ET.SubElement(scenComp,tag='Value')
                        gw_supply.attrib={'name':'water_supply'}
                        gw_supply.text=np_gw[gw]
                        #Sean climate impacts xmls
                        hydro=ET.SubElement(scenComp,tag='Value')
                        hydro.attrib={'name':'climate_hydro'}
                        hydro.text=np_hydropower[gcm]
                        cropyield=ET.SubElement(scenComp,tag='Value')
                        cropyield.attrib={'name':'aglu'}
                        cropyield.text=np_crop_yield[gcm][ag]
                        runoff=ET.SubElement(scenComp,tag='Value')
                        runoff.attrib={'name':'climate_runoff'}
                        #expanded vs restricted reservoir storage
                        runoff.text=np_water_supply[gcm][res]
                        #aglu
                        food=ET.SubElement(scenComp,tag='Value')
                        food.text=np_aglu[ag,0]
                        food.attrib={'name': 'aglu'}
                        mgmt=ET.SubElement(scenComp,tag='Value')
                        mgmt.text=np_aglu[ag,1]
                        mgmt.attrib={'name': 'aglu'}
                        #the rest of ssp elements (tied to pop/gdp now but can change to aglu by indexing for ag)
                        soc=ET.SubElement(scenComp,tag='Value')
                        soc.text=np_ssps[ssp]
                        soc.attrib={'name': 'socioeconomics'}
                        ind=ET.SubElement(scenComp,tag='Value')
                        ind.text=np_ind[ssp,0]
                        ind.attrib={'name':'ind'}
                        cem=ET.SubElement(scenComp,tag='Value')
                        cem.text=np_ind[ssp,1]
                        cem.attrib={'name':'cement'}
                        trans=ET.SubElement(scenComp,tag='Value')
                        trans.text=np_trans[ssp]
                        trans.attrib={'name':'trn'}
                        build=ET.SubElement(scenComp,tag='Value')
                        build.text=np_build[ssp]
                        build.attrib={'name':'bld'}
                        ccs=ET.SubElement(scenComp,tag='Value')
                        ccs.text=np_ccs[ssp]
                        ccs.attrib={'name':'ccs'}
                        fossil=ET.SubElement(scenComp,tag='Value')
                        fossil.text=np_fossil[ssp]
                        fossil.attrib={'name':'resource_extraction'}
                        nonco21=ET.SubElement(scenComp,tag='Value')
                        nonco21.text=np_nonco21[ssp]
                        nonco21.attrib={'name':'nonco2'}
                        nonco22=ET.SubElement(scenComp,tag='Value')
                        nonco22.text=np_nonco22[ssp]
                        nonco22.attrib={'name':'nonco2'}
                        neg=ET.SubElement(scenComp,tag='Value')
                        neg.attrib={'name':'bio_neg_emiss_budget'}
                        neg.text=np_neg[ssp]
                        #Neal's water demand xmls
                        waterinput=ET.SubElement(scenComp,tag='Value')
                        waterinput.attrib={'name':'water_input'}
                        waterinput.text=np_water_input[ssp]
                        electricitywatercoef=ET.SubElement(scenComp,tag='Value')
                        electricitywatercoef.attrib={'name':'electricity_water_coef'}
                        electricitywatercoef.text=np_electricity_water_coefs[ssp]
                        electricitywater=ET.SubElement(scenComp,tag='Value')
                        electricitywater.attrib={'name':'electricity_water'}
                        electricitywater.text=np_electricity_water[ssp]
                        resbio=ET.SubElement(scenComp,tag='Value')
                        resbio.attrib={'name':'resbio'}
                        resbio.text=np_resbio[ssp]
                        waterdemandindustry=ET.SubElement(scenComp,tag='Value')
                        waterdemandindustry.attrib={'name':'water_demand_industry'}
                        waterdemandindustry.text=np_water_demand_industry[ssp]
                        waterdemandmunicipal=ET.SubElement(scenComp,tag='Value')
                        waterdemandmunicipal.attrib={'name':'water_demand_municipal'}
                        waterdemandmunicipal.text=np_water_demand_municipal[ssp]


                        #change the scenario name
                        scen=('ssp_socio'+str(ssp+1)+'_ag'+str(ag+1)+'_gw'+gw_list[gw]+'_'+res_list[res]+'_'+gcm_list[gcm]+'_NDC_Tax_'+lud_list[lud])
                        root[2][0].text=scen
                        root[0][4].text='../output/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/db_'+scen

                        if ssp==0:
                            renew=ET.SubElement(scenComp,tag='Value')
                            renew.attrib={'name':'share_weights'}
                            renew.text='../input/extra/renewable_shareweights_ssp1_32.xml'
                            wind=ET.SubElement(scenComp,tag='Value')
                            wind.attrib={'name':'wind'}
                            wind.text='../input/gcam-data-system/xml/energy-xml/wind_adv.xml'
                            solar=ET.SubElement(scenComp,tag='Value')
                            solar.attrib={'name':'solar'}
                            solar.text='../input/gcam-data-system/xml/energy-xml/solar_adv.xml'
                            geo=ET.SubElement(scenComp,tag='Value')
                            geo.attrib={'name':'geothermal'}
                            geo.text='../input/gcam-data-system/xml/energy-xml/geo_adv.xml'
                            geotech=ET.SubElement(scenComp,tag='Value')
                            geotech.attrib={'name':'geothermal'}
                            geotech.text='../input/gcam-data-system/xml/energy-xml/geo_tech_adv.xml'
                            nuc=ET.SubElement(scenComp,tag='Value')
                            nuc.attrib={'name':'nuclear'}
                            nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_low.xml'
                            ccs2=ET.SubElement(scenComp,tag='Value')
                            ccs2.attrib={'name':'ccs'}
                            ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
                            nonco23=ET.SubElement(scenComp,tag='Value')
                            nonco23.attrib={'name':'nonco2'}
                            nonco23.text='../input/gcam-data-system/xml/emissions-xml/MACC_TC_SSP1_IRR_MGMT.xml'
                            tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_soc/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/'+scen+'.xml')
                            scenComp.remove(renew)
                            scenComp.remove(wind)
                            scenComp.remove(solar)
                            scenComp.remove(geo)
                            scenComp.remove(geotech)
                            scenComp.remove(nuc)
                            scenComp.remove(ccs2)
                            scenComp.remove(nonco23)
                        elif ssp==1:
                            ccs2=ET.SubElement(scenComp,tag='Value')
                            ccs2.attrib={'name':'ccs'}
                            ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
                            tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_soc/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/'+scen+'.xml')
                            scenComp.remove(ccs2)
                        elif ssp==2:
                            wind=ET.SubElement(scenComp,tag='Value')
                            wind.attrib={'name':'wind'}
                            wind.text='../input/gcam-data-system/xml/energy-xml/wind_low.xml'
                            solar=ET.SubElement(scenComp,tag='Value')
                            solar.attrib={'name':'solar'}
                            solar.text='../input/gcam-data-system/xml/energy-xml/solar_low.xml'
                            geo=ET.SubElement(scenComp,tag='Value')
                            geo.attrib={'name':'geothermal'}
                            geo.text='../input/gcam-data-system/xml/energy-xml/geo_low.xml'
                            bio=ET.SubElement(scenComp,tag='Value')
                            bio.attrib={'name':'bio'}
                            bio.text='../input/gcam-data-system/xml/energy-xml/en_transformation_low.xml'
                            bio2=ET.SubElement(scenComp,tag='Value')
                            bio2.attrib={'name':'bio'}
                            bio2.text='../input/gcam-data-system/xml/energy-xml/elec_bio_low.xml'
                            nuc=ET.SubElement(scenComp,tag='Value')
                            nuc.attrib={'name':'nuclear'}
                            nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_low.xml'
                            ccs2=ET.SubElement(scenComp,tag='Value')
                            ccs2.attrib={'name':'ccs'}
                            ccs2.text='../input/gcam-data-system/xml/energy-xml/no_offshore_ccs.xml'
                            biotrade=ET.SubElement(scenComp,tag='Value')
                            biotrade.attrib={'name':'bio_trade'}
                            biotrade.text='../input/gcam-data-system/xml/aglu-xml/ssp3_bio_trade.xml'

                            tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_soc/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/'+scen+'.xml')

                            scenComp.remove(wind)
                            scenComp.remove(solar)
                            scenComp.remove(geo)
                            scenComp.remove(bio)
                            scenComp.remove(bio2)
                            scenComp.remove(nuc)
                            scenComp.remove(ccs2)
                            scenComp.remove(biotrade)
                        elif ssp==3:
                            wind=ET.SubElement(scenComp,tag='Value')
                            wind.attrib={'name':'wind'}
                            wind.text='../input/gcam-data-system/xml/energy-xml/wind_adv.xml'
                            solar=ET.SubElement(scenComp,tag='Value')
                            solar.attrib={'name':'solar'}
                            solar.text='../input/gcam-data-system/xml/energy-xml/solar_adv.xml'
                            geo=ET.SubElement(scenComp,tag='Value')
                            geo.attrib={'name':'geothermal'}
                            geo.text='../input/gcam-data-system/xml/energy-xml/geo_adv.xml'
                            geotech=ET.SubElement(scenComp,tag='Value')
                            geotech.attrib={'name':'geothermal'}
                            geotech.text='../input/gcam-data-system/xml/energy-xml/geo_tech_adv.xml'
                            nuc=ET.SubElement(scenComp,tag='Value')
                            nuc.attrib={'name':'nuclear'}
                            nuc.text='../input/gcam-data-system/xml/energy-xml/nuclear_adv.xml'
                            trade=ET.SubElement(scenComp,tag='Value')
                            trade.attrib={'name':'trade'}
                            trade.text='../input/gcam-data-system/xml/aglu-xml/ssp4_trade.xml'
                            biotrade=ET.SubElement(scenComp,tag='Value')
                            biotrade.attrib={'name':'bio_trade'}
                            biotrade.text='../input/gcam-data-system/xml/aglu-xml/ssp4_bio_trade.xml'

                            tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_soc/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/'+scen+'.xml')

                            scenComp.remove(wind)
                            scenComp.remove(solar)
                            scenComp.remove(geo)
                            scenComp.remove(geotech)
                            scenComp.remove(nuc)
                            scenComp.remove(trade)
                            scenComp.remove(biotrade)

                        elif ssp==4:
                            nonco23=ET.SubElement(scenComp,tag='Value')
                            nonco23.attrib={'name':'nonco2'}
                            nonco23.text='../input/gcam-data-system/xml/emissions-xml/MACC_TC_SSP2_IRR_MGMT.xml'

                            tree.write('/cluster/tufts/lamontagnelab/fdolan03/GCAM/config_files/ssp_soc/'+'ssp_socio'+str(ssp+1)+'/ag'+str(ag+1)+'/'+scen+'.xml')

                            scenComp.remove(nonco23)

                        #tree.write('/cluster/home/fdolan03/jupyter/config/'+'ssp'+str(ssp+1)+'/ag'+str(ag+1)+'/ssp'+str(ssp+1)+'ag'+str(ag+1)+.xml')
                        scenComp.remove(soc)
                        scenComp.remove(food)
                        scenComp.remove(mgmt)
                        scenComp.remove(ind)
                        scenComp.remove(cem)
                        scenComp.remove(trans)
                        scenComp.remove(build)
                        scenComp.remove(ccs)
                        scenComp.remove(fossil)
                        scenComp.remove(nonco21)
                        scenComp.remove(nonco22)
                        scenComp.remove(neg)
                        scenComp.remove(waterinput)
                        scenComp.remove(electricitywatercoef)
                        scenComp.remove(electricitywater)
                        scenComp.remove(resbio)
                        scenComp.remove(waterdemandindustry)
                        scenComp.remove(waterdemandmunicipal)

                        scenComp.remove(hydro)
                        scenComp.remove(cropyield)
                        scenComp.remove(runoff)
                        scenComp.remove(gw_supply)

                        scenComp.remove(lud_type)
